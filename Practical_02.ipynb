# %% [markdown]
# <a href="https://colab.research.google.com/github/KHUSHNADPARA-max/CPP/blob/main/Practical_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io

# %%
import pandas

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-eaed7860-cb1b-4ffd-bbe7-e58a57c0e02a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eaed7860-cb1b-4ffd-bbe7-e58a57c0e02a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pandas.read_csv(io.BytesIO(uploaded['NBA_2018-19_Season - NBA_2018-19_Season.csv']))

# %%
df.head(5)
# Out:
#   Conference  Division            Team         Player  Age  Games  \
# 0    Eastern  Atlantic  Boston Celtics   Jayson Tatum   20     79
# 1    Eastern  Atlantic  Boston Celtics   Kyrie Irving   26     67
# 2    Eastern  Atlantic  Boston Celtics   Marcus Smart   24     80
# 3    Eastern  Atlantic  Boston Celtics  Marcus Morris   29     75
# 4    Eastern  Atlantic  Boston Celtics     Al Horford   32     68
#
#    Games Started  Minutes Played  Field Goals  Field Goal Attempts  ...  \
# 0             79            2455          466                 1036  ...
# 1             67            2214          604                 1241  ...
# 2             60            2200          239                  567  ...
# 3             53            2091          377                  844  ...
# 4             68            1973          387                  723  ...
#
#    Free Throw Percentage  Offensive Rebounds  Defensive Rebounds  \
# 0                  0.855                  70                 407
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 0 to 621
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Conference                       622 non-null    object
#  1   Division                         622 non-null    object
#  2   Team                             622 non-null    object
#  3   Player                           622 non-null    object
#  4   Age                              622 non-null    int64
#  5   Games                            622 non-null    int64
#  6   Games Started                    622 non-null    int64
#  7   Minutes Played                   622 non-null    int64
#  8   Field Goals                      622 non-null    int64
#  9   Field Goal Attempts              622 non-null    int64
#  10  Field Goal Percentage            616 non-null    float64
#  11  3-Point Field Goals              622 non-null    int64
# ...

# %%
df['Age'].min()
# Out:
# 19

# %%
df.groupby('Age').mean()
# Out:
# <ipython-input-8-16c96bc1028d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()
#          Games  Games Started  Minutes Played  Field Goals  \
# Age
# 19   39.727273      22.363636      898.000000   167.272727
# 20   55.000000      32.520000     1256.720000   203.760000
# 21   36.060000      15.400000      724.100000   119.620000
# 22   38.280000      15.800000      827.900000   146.480000
# 23   33.417910      13.417910      715.761194   124.343284
# 24   45.226415      21.094340     1007.264151   167.679245
# 25   45.673077      17.750000     1013.673077   176.057692
# 26   41.909091      19.000000      998.327273   178.236364
# 27   41.727273      18.431818      968.159091   155.886364
# 28   41.020000      23.240000     1034.420000   181.220000
# ...

# %% [markdown]
# Question 1. Find out the average age of the player who have played for NBA?

# %%
df['Age'].mean()
# Out:
# 26.04823151125402

# %% [markdown]
# Question 2. Find out that each player have played how many games?

# %%
df[['Player', 'Games']]
# Out:
#                    Player  Games
# 0            Jayson Tatum     79
# 1            Kyrie Irving     67
# 2            Marcus Smart     80
# 3           Marcus Morris     75
# 4              Al Horford     68
# ..                    ...    ...
# 617           Salah Mejri     36
# 618          Courtney Lee     22
# 619           Daryl Macon      8
# 620  Kostas Antetokounmpo      2
# 621          Ray Spalding      1
#
# [622 rows x 2 columns]

# %% [markdown]
# Question 3. Total how many teams are there in NBA?
#
# https://colab.research.google.com/drive/1xcgjqaebmnFI-7x0As29tWWPaNCy--NI#scrollTo=YzxoA9i9NoX9&printMode=true

# %%
df['Team'].nunique()
# Out:
# 30

# %% [markdown]
# Question 4. What is the minimum age of the player that have played for NBA?

# %%
df['Age'].min()
# Out:
# 19

# %% [markdown]
# Question 5. What is the Maximum age of the player that have played for NBA and display its details?

# %%
df['Age'].max()
# Out:
# 42

# %%
df.loc[df['Age']==42]
# Out:
#     Conference   Division           Team        Player  Age  Games  \
# 302    Eastern  Southeast  Atlanta Hawks  Vince Carter   42     76
#
#      Games Started  Minutes Played  Field Goals  Field Goal Attempts  ...  \
# 302              9            1330          196                  468  ...
#
#      Free Throw Percentage  Offensive Rebounds  Defensive Rebounds  \
# 302                  0.712                  31                 163
#
#      Total Rebounds  Assists  Steals  Blocks  Turnovers  Personal Fouls  \
# 302             194       87      44      27         48             141
#
#      Points
# 302     562
#
# [1 rows x 30 columns]

# %% [markdown]
# Question 6. Find out how many games have been organized in Eastern region.

# %%
east = df[df.Conference == 'Eastern'].Games.sum()
east
# Out:
# 12976

# %% [markdown]
# Question 7. Find out the how many regions are there, where the games have been organized?

# %%
r = df[['Conference']].nunique().Conference
r
# Out:
# 2

# %% [markdown]
# Question 8. Display the list of the player who have played in the team called "Boston Celtics".

# %%
df[df.Team == 'Boston Celtics']
# Out:
#    Conference  Division            Team              Player  Age  Games  \
# 0     Eastern  Atlantic  Boston Celtics        Jayson Tatum   20     79
# 1     Eastern  Atlantic  Boston Celtics        Kyrie Irving   26     67
# 2     Eastern  Atlantic  Boston Celtics        Marcus Smart   24     80
# 3     Eastern  Atlantic  Boston Celtics       Marcus Morris   29     75
# 4     Eastern  Atlantic  Boston Celtics          Al Horford   32     68
# 5     Eastern  Atlantic  Boston Celtics        Jaylen Brown   22     74
# 6     Eastern  Atlantic  Boston Celtics      Gordon Hayward   28     72
# 7     Eastern  Atlantic  Boston Celtics        Terry Rozier   24     79
# 8     Eastern  Atlantic  Boston Celtics        Daniel Theis   26     66
# 9     Eastern  Atlantic  Boston Celtics         Aron Baynes   32     51
# 10    Eastern  Atlantic  Boston Celtics        Semi Ojeleye   24     56
# 11    Eastern  Atlantic  Boston Celtics      Brad Wanamaker   29     36
# ...

# %% [markdown]
# Question 9. Find out the total number of games organized in each division?

# %%
df.groupby('Division')['Games'].sum()
# Out:
# Division
# Atlantic     4319
# Central      4345
# Northwest    4396
# Pacific      4453
# Southeast    4312
# Southwest    4276
# Name: Games, dtype: int64

# %% [markdown]
# Question 10. Which player have scored the maximum number of goals?

# %%
max_goal = df[['Field Goals']].max()
df[df['Field Goals']== max_goal['Field Goals']]
# Out:
#     Conference   Division             Team        Player  Age  Games  \
# 514    Western  Southwest  Houston Rockets  James Harden   29     78
#
#      Games Started  Minutes Played  Field Goals  Field Goal Attempts  ...  \
# 514             78            2867          843                 1909  ...
#
#      Free Throw Percentage  Offensive Rebounds  Defensive Rebounds  \
# 514                  0.879                  66                 452
#
#      Total Rebounds  Assists  Steals  Blocks  Turnovers  Personal Fouls  \
# 514             518      586     158      58        387             244
#
#      Points
# 514    2818
#
# [1 rows x 30 columns]

# %% [markdown]
# Question 11. Which player have the lowest number of personal fouls?

# %%
min_fault = df[['Personal Fouls']].min()
df[df['Personal Fouls'] == min_fault['Personal Fouls']][['Player','Personal Fouls']]
# Out:
#                     Player  Personal Fouls
# 16             Greg Monroe               0
# 130           Trevon Duval               0
# 147           Ike Anigbogu               0
# 165  Sviatoslav Mykhailiuk               0
# 167            Zach Lofton               0
# 189             Tyler Ulis               0
# 215           Kobi Simmons               0
# 216           John Holland               0
# 233           Troy Caupain               0
# 249            J.P. Macura               0
# 267            Yante Maten               0
# 268          Emanuel Terry               0
# 292           John Jenkins               0
# 293            Okaro White               0
# 315          Jordan Sibert               0
# 385         Donte Grantham               0
# 386            Tyler Davis               0
# 387            Jawun Evans               0
# 408            Mitch Creek               0
# 489           Andre Ingram               0
# 512            George King               0
# ...

# %% [markdown]
# Question 12. Which player have attempted the 3-points field goals the highest time and what are the percentage of it?

# %%
maxAtt = df[['3-Point Field Goal Attempts']].max()
df[df['3-Point Field Goal Attempts'] == maxAtt['3-Point Field Goal Attempts']][['Player', '3-Point Field Goal Attempts', '3-Point Field

# %% [markdown]
# Question 13. What is the average point scored by all the players?

# %%
df['Average Points'] = df["Games"]/df["Points"]
df[['Player','Average Points']]
# Out:
#                    Player  Average Points
# 0            Jayson Tatum        0.063556
# 1            Kyrie Irving        0.041980
# 2            Marcus Smart        0.112994
# 3           Marcus Morris        0.071702
# 4              Al Horford        0.073514
# ..                    ...             ...
# 617           Salah Mejri        0.255319
# 618          Courtney Lee        0.275000
# 619           Daryl Macon        0.275862
# 620  Kostas Antetokounmpo        1.000000
# 621          Ray Spalding             inf
#
# [622 rows x 2 columns]

# %% [markdown]
# Question 14. Find out the average age of players division wise?

# %%
df.groupby("Division")["Age"].mean()
# Out:
# Division
# Atlantic     25.728972
# Central      25.736364
# Northwest    25.709677
# Pacific      26.104762
# Southeast    25.979798
# Southwest    26.981481
# Name: Age, dtype: float64

# %% [markdown]
# Question 15. Find out the total number of fouls in each team?

# %%
df.groupby("Team")["Personal Fouls"].sum()
# Out:
# Team
# Atlanta Hawks             1932
# Boston Celtics            1670
# Brooklyn Nets             1763
# Charlotte Hornets         1550
# Chicago Bulls             1663
# Cleveland Cavaliers       1642
# Dallas Mavericks          1650
# Denver Nuggets            1644
# Detroit Pistons           1811
# Golden State Warriors     1757
# Houston Rockets           1803
# Indiana Pacers            1594
# Los Angeles Clippers      1913
# Los Angeles Lakers        1701
# Memphis Grizzlies         1801
# Miami Heat                1712
# Milwaukee Bucks           1608
# Minnesota Timberwolves    1664
# New Orleans Pelicans      1732
# New York Knicks           1713
# Oklahoma City Thunder     1839
# Orlando Magic             1526
# Philadelphia 76ers        1745
# Phoenix Suns              1932
# Portland Trail Blazers    1669
# Sacramento Kings          1751
# San Antonio Spurs         1487
# Toronto Raptors           1724
# Utah Jazz                 1728
# Washington Wizards        1701
# ...
